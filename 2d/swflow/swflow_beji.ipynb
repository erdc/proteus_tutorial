# %% [markdown]
# # 2D SWFlow - Periodic waves over submerged bar
# ------------------------------------------------------------------------------------------
#
# This notebook uses Proteus to reproduce the 1993/1994 experiments of Beji and Battjes to investigate the propagation of periodic waves over a submerged bar.
#
# The original domain is defined to be D=[0, 37.3m]x[0,4m]. However, we introduce 6m (on the left) for wave generation and 12.7m (on the right) for wave absorption so the full computational domain is D=[-6, 50m]x[0,4m]. The topography (interchanged with the bathymetry nomenclature) is a trapezoidal profile simulating a sand bar. The periodic waves are generated on the left side of the domain and propagate to the right.
#
# ### References
#
# - S. Beji and J. Battjes. Numerical simulation of nonlinear wave propagation over a bar. Coastal Engineering,         23(1):1 – 16, 1994. [https://doi.org/10.1016/0378-3839(94)90012-4](https://doi.org/10.1016/0378-3839(94)90012-4)

# %% [markdown]
# # Running the benchmark via the terminal
#
# The `parun` script can be to execute the python script file: `reef_island_runup.py`. There are several argument that can be supplied to the `parun` script to define various runtime options. All available options are listed when executing `parun -h` in the command line. Common command-line options are as follows:
#
# **Option** | **Description**
# :---: | :---:
#  -v   | Print logging information to standard output
#  -O PETSCOPTIONSFILE  | Text file of options to pass to Petsc library
#  -D DATADIR | Set data directory for output storage
#  -l LOGLEVEL | Store runtime information at the log level, 0 = none, 10 = everything
#  -b BATCHFILENAME | Text file of auxiliary commands to execute along with main program
#  -G gatherArchive | Collect data files into single file at end of simulation (will require more computational resources on large runs)
#  -H hotStart | Use the last step in the archive as the initial condition and continue appending to the archive
#  --SWEs | To consider SWEs applications
#
#
# To run the script on more than one rank, one can invoke the following: `mpiexec -n <number of cores>` before the use of `parun` in the command line.

# %% [markdown]
# ## Context options for run file
#
# Most (if not all) Proteus run files `benchmark_name.py` (in this case `beji_periodic.py`) contain run time options specific to the model at hand. Here are some run time options for this particular example. For exact options, see the run file.
#
# **Option** | **Description**
# :---: | :---:
#  sw_model | sw_model = {0,1} for {SWEs,DSWEs}
#  final_time  | Final time for simulation
#  dt_output | Time interval to output solution
#  mannings | Mannings roughness coefficient
#  still_water_depth | Still water height above floor
#  wave_period | Period of the waves
#  wave_height | Height of the waves
#
#
# To modify the context options at run time, include the `-C` flag followed by `"option1=True option2=2 ..."`.

# %%
# Clean up previous data directory if it exists
# !rm swflow_data/reef*
# Out:
# rm: cannot remove 'swflow_data/reef*': No such file or directory

# %%
# Then we run 
# !PATH=/opt/proteus/linux/bin:$PATH mpiexec -np 2 parun --SWEs beji_periodic.py -v -l1 -C "final_time=25." -D run_data
# Out:
# [       0] Running Proteus version 1.8.0.dev0
# Constructing GN_SW2DCV<CompKernelTemplate<2,4,3,3,3,3>());
# Constructing GN_SW2DCV<CompKernelTemplate<2,4,3,3,3,3>());
# 2  nSpace_global
# [       3] Setting initial conditions
# [       4] Starting time stepping
# [       4] ==============================================================
# [       4] Solving over interval [ 0.00000e+00, 1.00000e-03]
# [       4] ==============================================================
# [       4] ==============================================================
# [       4] Solving over interval [ 1.00000e-03, 1.00000e-01]
# [       4] ==============================================================
# [       7] ==============================================================
# [       7] Solving over interval [ 1.00000e-01, 2.00000e-01]
# [       7] ==============================================================
# [       9] ==============================================================
# [       9] Solving over interval [ 2.00000e-01, 3.00000e-01]
# [       9] ==============================================================
# [      12] ==============================================================
# [      12] Solving over interval [ 3.00000e-01, 4.00000e-01]
# [      12] ==============================================================
# [      14] ==============================================================
# [      14] Solving over interval [ 4.00000e-01, 5.00000e-01]
# [      14] ==============================================================
# [      17] ==============================================================
# [      17] Solving over interval [ 5.00000e-01, 6.00000e-01]
# [      17] ==============================================================
# [      19] ==============================================================
# [      19] Solving over interval [ 6.00000e-01, 7.00000e-01]
# [      19] ==============================================================
# [      22] ==============================================================
# [      22] Solving over interval [ 7.00000e-01, 8.00000e-01]
# [      22] ==============================================================
# [      24] ==============================================================
# [      24] Solving over interval [ 8.00000e-01, 9.00000e-01]
# [      24] ==============================================================
# [      27] ==============================================================
# [      27] Solving over interval [ 9.00000e-01, 1.00000e+00]
# [      27] ==============================================================
# [      29] ==============================================================
# [      29] Solving over interval [ 1.00000e+00, 1.10000e+00]
# [      29] ==============================================================
# [      32] ==============================================================
# [      32] Solving over interval [ 1.10000e+00, 1.20000e+00]
# [      32] ==============================================================
# [      34] ==============================================================
# [      34] Solving over interval [ 1.20000e+00, 1.30000e+00]
# [      34] ==============================================================
# [      37] ==============================================================
# [      37] Solving over interval [ 1.30000e+00, 1.40000e+00]
# [      37] ==============================================================
# [      39] ==============================================================
# [      39] Solving over interval [ 1.40000e+00, 1.50000e+00]
# [      39] ==============================================================
# [      42] ==============================================================
# [      42] Solving over interval [ 1.50000e+00, 1.60000e+00]
# [      42] ==============================================================
# [      45] ==============================================================
# [      45] Solving over interval [ 1.60000e+00, 1.70000e+00]
# [      45] ==============================================================
# [      47] ==============================================================
# [      47] Solving over interval [ 1.70000e+00, 1.80000e+00]
# [      47] ==============================================================
# [      50] ==============================================================
# [      50] Solving over interval [ 1.80000e+00, 1.90000e+00]
# [      50] ==============================================================
# [      52] ==============================================================
# [      52] Solving over interval [ 1.90000e+00, 2.00000e+00]
# [      52] ==============================================================
# [      55] ==============================================================
# [      55] Solving over interval [ 2.00000e+00, 2.10000e+00]
# [      55] ==============================================================
# [      57] ==============================================================
# [      57] Solving over interval [ 2.10000e+00, 2.20000e+00]
# [      57] ==============================================================
# [      59] ==============================================================
# [      59] Solving over interval [ 2.20000e+00, 2.30000e+00]
# [      59] ==============================================================
# [      62] ==============================================================
# [      62] Solving over interval [ 2.30000e+00, 2.40000e+00]
# [      62] ==============================================================
# [      64] ==============================================================
# [      64] Solving over interval [ 2.40000e+00, 2.50000e+00]
# [      64] ==============================================================
# [      67] ==============================================================
# [      67] Solving over interval [ 2.50000e+00, 2.60000e+00]
# [      67] ==============================================================
# [      69] ==============================================================
# [      69] Solving over interval [ 2.60000e+00, 2.70000e+00]
# [      69] ==============================================================
# [      72] ==============================================================
# [      72] Solving over interval [ 2.70000e+00, 2.80000e+00]
# [      72] ==============================================================
# [      74] ==============================================================
# [      74] Solving over interval [ 2.80000e+00, 2.90000e+00]
# [      74] ==============================================================
# [      77] ==============================================================
# [      77] Solving over interval [ 2.90000e+00, 3.00000e+00]
# [      77] ==============================================================
# [      79] ==============================================================
# [      79] Solving over interval [ 3.00000e+00, 3.10000e+00]
# [      79] ==============================================================
# [      82] ==============================================================
# [      82] Solving over interval [ 3.10000e+00, 3.20000e+00]
# [      82] ==============================================================
# [      84] ==============================================================
# [      84] Solving over interval [ 3.20000e+00, 3.30000e+00]
# [      84] ==============================================================
# [      87] ==============================================================
# [      87] Solving over interval [ 3.30000e+00, 3.40000e+00]
# [      87] ==============================================================
# [      89] ==============================================================
# [      89] Solving over interval [ 3.40000e+00, 3.50000e+00]
# [      89] ==============================================================
# [      92] ==============================================================
# [      92] Solving over interval [ 3.50000e+00, 3.60000e+00]
# [      92] ==============================================================
# [      94] ==============================================================
# [      94] Solving over interval [ 3.60000e+00, 3.70000e+00]
# [      94] ==============================================================
# [      97] ==============================================================
# [      97] Solving over interval [ 3.70000e+00, 3.80000e+00]
# [      97] ==============================================================
# [      99] ==============================================================
# [      99] Solving over interval [ 3.80000e+00, 3.90000e+00]
# [      99] ==============================================================
# [     102] ==============================================================
# [     102] Solving over interval [ 3.90000e+00, 4.00000e+00]
# [     102] ==============================================================
# [     105] ==============================================================
# [     105] Solving over interval [ 4.00000e+00, 4.10000e+00]
# [     105] ==============================================================
# [     107] ==============================================================
# [     107] Solving over interval [ 4.10000e+00, 4.20000e+00]
# [     107] ==============================================================
# [     110] ==============================================================
# [     110] Solving over interval [ 4.20000e+00, 4.30000e+00]
# [     110] ==============================================================
# [     113] ==============================================================
# [     113] Solving over interval [ 4.30000e+00, 4.40000e+00]
# [     113] ==============================================================
# [     115] ==============================================================
# [     115] Solving over interval [ 4.40000e+00, 4.50000e+00]
# [     115] ==============================================================
# [     118] ==============================================================
# [     118] Solving over interval [ 4.50000e+00, 4.60000e+00]
# [     118] ==============================================================
# [     120] ==============================================================
# [     120] Solving over interval [ 4.60000e+00, 4.70000e+00]
# [     120] ==============================================================
# [     123] ==============================================================
# [     123] Solving over interval [ 4.70000e+00, 4.80000e+00]
# [     123] ==============================================================
# [     126] ==============================================================
# [     126] Solving over interval [ 4.80000e+00, 4.90000e+00]
# [     126] ==============================================================
# [     128] ==============================================================
# [     128] Solving over interval [ 4.90000e+00, 5.00000e+00]
# [     128] ==============================================================
# [     131] ==============================================================
# [     131] Solving over interval [ 5.00000e+00, 5.10000e+00]
# [     131] ==============================================================
# [     133] ==============================================================
# [     133] Solving over interval [ 5.10000e+00, 5.20000e+00]
# [     133] ==============================================================
# [     135] ==============================================================
# [     135] Solving over interval [ 5.20000e+00, 5.30000e+00]
# [     135] ==============================================================
# [     138] ==============================================================
# [     138] Solving over interval [ 5.30000e+00, 5.40000e+00]
# [     138] ==============================================================
# [     141] ==============================================================
# [     141] Solving over interval [ 5.40000e+00, 5.50000e+00]
# [     141] ==============================================================
# [     143] ==============================================================
# [     143] Solving over interval [ 5.50000e+00, 5.60000e+00]
# [     143] ==============================================================
# [     146] ==============================================================
# [     146] Solving over interval [ 5.60000e+00, 5.70000e+00]
# [     146] ==============================================================
# [     148] ==============================================================
# [     148] Solving over interval [ 5.70000e+00, 5.80000e+00]
# [     148] ==============================================================
# [     151] ==============================================================
# [     151] Solving over interval [ 5.80000e+00, 5.90000e+00]
# [     151] ==============================================================
# [     153] ==============================================================
# [     153] Solving over interval [ 5.90000e+00, 6.00000e+00]
# [     153] ==============================================================
# [     156] ==============================================================
# [     156] Solving over interval [ 6.00000e+00, 6.10000e+00]
# [     156] ==============================================================
# [     158] ==============================================================
# [     158] Solving over interval [ 6.10000e+00, 6.20000e+00]
# [     158] ==============================================================
# [     160] ==============================================================
# [     160] Solving over interval [ 6.20000e+00, 6.30000e+00]
# [     160] ==============================================================
# [     163] ==============================================================
# [     163] Solving over interval [ 6.30000e+00, 6.40000e+00]
# [     163] ==============================================================
# [     165] ==============================================================
# [     165] Solving over interval [ 6.40000e+00, 6.50000e+00]
# [     165] ==============================================================
# [     168] ==============================================================
# [     168] Solving over interval [ 6.50000e+00, 6.60000e+00]
# [     168] ==============================================================
# [     170] ==============================================================
# [     170] Solving over interval [ 6.60000e+00, 6.70000e+00]
# [     170] ==============================================================
# [     173] ==============================================================
# [     173] Solving over interval [ 6.70000e+00, 6.80000e+00]
# [     173] ==============================================================
# [     175] ==============================================================
# [     175] Solving over interval [ 6.80000e+00, 6.90000e+00]
# [     175] ==============================================================
# [     178] ==============================================================
# [     178] Solving over interval [ 6.90000e+00, 7.00000e+00]
# [     178] ==============================================================
# [     180] ==============================================================
# [     180] Solving over interval [ 7.00000e+00, 7.10000e+00]
# [     180] ==============================================================
# [     183] ==============================================================
# [     183] Solving over interval [ 7.10000e+00, 7.20000e+00]
# [     183] ==============================================================
# [     185] ==============================================================
# [     185] Solving over interval [ 7.20000e+00, 7.30000e+00]
# [     185] ==============================================================
# [     188] ==============================================================
# [     188] Solving over interval [ 7.30000e+00, 7.40000e+00]
# [     188] ==============================================================
# [     190] ==============================================================
# [     190] Solving over interval [ 7.40000e+00, 7.50000e+00]
# [     190] ==============================================================
# [     193] ==============================================================
# [     193] Solving over interval [ 7.50000e+00, 7.60000e+00]
# [     193] ==============================================================
# [     195] ==============================================================
# [     195] Solving over interval [ 7.60000e+00, 7.70000e+00]
# [     195] ==============================================================
# [     198] ==============================================================
# [     198] Solving over interval [ 7.70000e+00, 7.80000e+00]
# [     198] ==============================================================
# [     201] ==============================================================
# [     201] Solving over interval [ 7.80000e+00, 7.90000e+00]
# [     201] ==============================================================
# [     203] ==============================================================
# [     203] Solving over interval [ 7.90000e+00, 8.00000e+00]
# [     203] ==============================================================
# [     205] ==============================================================
# [     205] Solving over interval [ 8.00000e+00, 8.10000e+00]
# [     205] ==============================================================
# [     208] ==============================================================
# [     208] Solving over interval [ 8.10000e+00, 8.20000e+00]
# [     208] ==============================================================
# [     210] ==============================================================
# [     210] Solving over interval [ 8.20000e+00, 8.30000e+00]
# [     210] ==============================================================
# [     213] ==============================================================
# [     213] Solving over interval [ 8.30000e+00, 8.40000e+00]
# [     213] ==============================================================
# [     215] ==============================================================
# [     215] Solving over interval [ 8.40000e+00, 8.50000e+00]
# [     215] ==============================================================
# [     218] ==============================================================
# [     218] Solving over interval [ 8.50000e+00, 8.60000e+00]
# [     218] ==============================================================
# [     220] ==============================================================
# [     220] Solving over interval [ 8.60000e+00, 8.70000e+00]
# [     220] ==============================================================
# [     223] ==============================================================
# [     223] Solving over interval [ 8.70000e+00, 8.80000e+00]
# [     223] ==============================================================
# [     225] ==============================================================
# [     225] Solving over interval [ 8.80000e+00, 8.90000e+00]
# [     225] ==============================================================
# [     228] ==============================================================
# [     228] Solving over interval [ 8.90000e+00, 9.00000e+00]
# [     228] ==============================================================
# [     230] ==============================================================
# [     230] Solving over interval [ 9.00000e+00, 9.10000e+00]
# [     230] ==============================================================
# [     233] ==============================================================
# [     233] Solving over interval [ 9.10000e+00, 9.20000e+00]
# [     233] ==============================================================
# [     235] ==============================================================
# [     235] Solving over interval [ 9.20000e+00, 9.30000e+00]
# [     235] ==============================================================
# [     238] ==============================================================
# [     238] Solving over interval [ 9.30000e+00, 9.40000e+00]
# [     238] ==============================================================
# [     240] ==============================================================
# [     240] Solving over interval [ 9.40000e+00, 9.50000e+00]
# [     240] ==============================================================
# [     243] ==============================================================
# [     243] Solving over interval [ 9.50000e+00, 9.60000e+00]
# [     243] ==============================================================
# [     245] ==============================================================
# [     245] Solving over interval [ 9.60000e+00, 9.70000e+00]
# [     245] ==============================================================
# [     248] ==============================================================
# [     248] Solving over interval [ 9.70000e+00, 9.80000e+00]
# [     248] ==============================================================
# [     250] ==============================================================
# [     250] Solving over interval [ 9.80000e+00, 9.90000e+00]
# [     250] ==============================================================
# [     253] ==============================================================
# [     253] Solving over interval [ 9.90000e+00, 1.00000e+01]
# [     253] ==============================================================
# [     255] ==============================================================
# [     255] Solving over interval [ 1.00000e+01, 1.01000e+01]
# [     255] ==============================================================
# [     258] ==============================================================
# [     258] Solving over interval [ 1.01000e+01, 1.02000e+01]
# [     258] ==============================================================
# [     260] ==============================================================
# [     260] Solving over interval [ 1.02000e+01, 1.03000e+01]
# [     260] ==============================================================
# [     263] ==============================================================
# [     263] Solving over interval [ 1.03000e+01, 1.04000e+01]
# [     263] ==============================================================
# [     266] ==============================================================
# [     266] Solving over interval [ 1.04000e+01, 1.05000e+01]
# [     266] ==============================================================
# [     268] ==============================================================
# [     268] Solving over interval [ 1.05000e+01, 1.06000e+01]
# [     268] ==============================================================
# [     271] ==============================================================
# [     271] Solving over interval [ 1.06000e+01, 1.07000e+01]
# [     271] ==============================================================
# [     273] ==============================================================
# [     273] Solving over interval [ 1.07000e+01, 1.08000e+01]
# [     273] ==============================================================
# [     276] ==============================================================
# [     276] Solving over interval [ 1.08000e+01, 1.09000e+01]
# [     276] ==============================================================
# [     278] ==============================================================
# [     278] Solving over interval [ 1.09000e+01, 1.10000e+01]
# [     278] ==============================================================
# [     281] ==============================================================
# [     281] Solving over interval [ 1.10000e+01, 1.11000e+01]
# [     281] ==============================================================
# [     283] ==============================================================
# [     283] Solving over interval [ 1.11000e+01, 1.12000e+01]
# [     283] ==============================================================
# [     286] ==============================================================
# [     286] Solving over interval [ 1.12000e+01, 1.13000e+01]
# [     286] ==============================================================
# [     288] ==============================================================
# [     288] Solving over interval [ 1.13000e+01, 1.14000e+01]
# [     288] ==============================================================
# [     291] ==============================================================
# [     291] Solving over interval [ 1.14000e+01, 1.15000e+01]
# [     291] ==============================================================
# [     293] ==============================================================
# [     293] Solving over interval [ 1.15000e+01, 1.16000e+01]
# [     293] ==============================================================
# [     296] ==============================================================
# [     296] Solving over interval [ 1.16000e+01, 1.17000e+01]
# [     296] ==============================================================
# [     299] ==============================================================
# [     299] Solving over interval [ 1.17000e+01, 1.18000e+01]
# [     299] ==============================================================
# [     301] ==============================================================
# [     301] Solving over interval [ 1.18000e+01, 1.19000e+01]
# [     301] ==============================================================
# [     304] ==============================================================
# [     304] Solving over interval [ 1.19000e+01, 1.20000e+01]
# [     304] ==============================================================
# [     306] ==============================================================
# [     306] Solving over interval [ 1.20000e+01, 1.21000e+01]
# [     306] ==============================================================
# [     308] ==============================================================
# [     308] Solving over interval [ 1.21000e+01, 1.22000e+01]
# [     308] ==============================================================
# [     311] ==============================================================
# [     311] Solving over interval [ 1.22000e+01, 1.23000e+01]
# [     311] ==============================================================
# [     313] ==============================================================
# [     313] Solving over interval [ 1.23000e+01, 1.24000e+01]
# [     313] ==============================================================
# [     316] ==============================================================
# [     316] Solving over interval [ 1.24000e+01, 1.25000e+01]
# [     316] ==============================================================
# [     318] ==============================================================
# [     318] Solving over interval [ 1.25000e+01, 1.26000e+01]
# [     318] ==============================================================
# [     321] ==============================================================
# [     321] Solving over interval [ 1.26000e+01, 1.27000e+01]
# [     321] ==============================================================
# [     323] ==============================================================
# [     323] Solving over interval [ 1.27000e+01, 1.28000e+01]
# [     323] ==============================================================
# [     326] ==============================================================
# [     326] Solving over interval [ 1.28000e+01, 1.29000e+01]
# [     326] ==============================================================
# [     328] ==============================================================
# [     328] Solving over interval [ 1.29000e+01, 1.30000e+01]
# [     328] ==============================================================
# [     331] ==============================================================
# [     331] Solving over interval [ 1.30000e+01, 1.31000e+01]
# [     331] ==============================================================
# [     333] ==============================================================
# [     333] Solving over interval [ 1.31000e+01, 1.32000e+01]
# [     333] ==============================================================
# [     336] ==============================================================
# [     336] Solving over interval [ 1.32000e+01, 1.33000e+01]
# [     336] ==============================================================
# [     338] ==============================================================
# [     338] Solving over interval [ 1.33000e+01, 1.34000e+01]
# [     338] ==============================================================
# [     341] ==============================================================
# [     341] Solving over interval [ 1.34000e+01, 1.35000e+01]
# [     341] ==============================================================
# [     343] ==============================================================
# [     343] Solving over interval [ 1.35000e+01, 1.36000e+01]
# [     343] ==============================================================
# [     346] ==============================================================
# [     346] Solving over interval [ 1.36000e+01, 1.37000e+01]
# [     346] ==============================================================
# [     348] ==============================================================
# [     348] Solving over interval [ 1.37000e+01, 1.38000e+01]
# [     348] ==============================================================
# [     351] ==============================================================
# [     351] Solving over interval [ 1.38000e+01, 1.39000e+01]
# [     351] ==============================================================
# [     353] ==============================================================
# [     353] Solving over interval [ 1.39000e+01, 1.40000e+01]
# [     353] ==============================================================
# [     356] ==============================================================
# [     356] Solving over interval [ 1.40000e+01, 1.41000e+01]
# [     356] ==============================================================
# [     359] ==============================================================
# [     359] Solving over interval [ 1.41000e+01, 1.42000e+01]
# [     359] ==============================================================
# [     361] ==============================================================
# [     361] Solving over interval [ 1.42000e+01, 1.43000e+01]
# [     361] ==============================================================
# [     364] ==============================================================
# [     364] Solving over interval [ 1.43000e+01, 1.44000e+01]
# [     364] ==============================================================
# [     366] ==============================================================
# [     366] Solving over interval [ 1.44000e+01, 1.45000e+01]
# [     366] ==============================================================
# [     369] ==============================================================
# [     369] Solving over interval [ 1.45000e+01, 1.46000e+01]
# [     369] ==============================================================
# [     371] ==============================================================
# [     371] Solving over interval [ 1.46000e+01, 1.47000e+01]
# [     371] ==============================================================
# [     374] ==============================================================
# [     374] Solving over interval [ 1.47000e+01, 1.48000e+01]
# [     374] ==============================================================
# [     376] ==============================================================
# [     376] Solving over interval [ 1.48000e+01, 1.49000e+01]
# [     376] ==============================================================
# [     378] ==============================================================
# [     378] Solving over interval [ 1.49000e+01, 1.50000e+01]
# [     378] ==============================================================
# [     381] ==============================================================
# [     381] Solving over interval [ 1.50000e+01, 1.51000e+01]
# [     381] ==============================================================
# [     383] ==============================================================
# [     383] Solving over interval [ 1.51000e+01, 1.52000e+01]
# [     383] ==============================================================
# [     386] ==============================================================
# [     386] Solving over interval [ 1.52000e+01, 1.53000e+01]
# [     386] ==============================================================
# [     388] ==============================================================
# [     388] Solving over interval [ 1.53000e+01, 1.54000e+01]
# [     388] ==============================================================
# [     391] ==============================================================
# [     391] Solving over interval [ 1.54000e+01, 1.55000e+01]
# [     391] ==============================================================
# [     393] ==============================================================
# [     393] Solving over interval [ 1.55000e+01, 1.56000e+01]
# [     393] ==============================================================
# [     396] ==============================================================
# [     396] Solving over interval [ 1.56000e+01, 1.57000e+01]
# [     396] ==============================================================
# [     398] ==============================================================
# [     398] Solving over interval [ 1.57000e+01, 1.58000e+01]
# [     398] ==============================================================
# [     401] ==============================================================
# [     401] Solving over interval [ 1.58000e+01, 1.59000e+01]
# [     401] ==============================================================
# [     404] ==============================================================
# [     404] Solving over interval [ 1.59000e+01, 1.60000e+01]
# [     404] ==============================================================
# [     406] ==============================================================
# [     406] Solving over interval [ 1.60000e+01, 1.61000e+01]
# [     406] ==============================================================
# [     409] ==============================================================
# [     409] Solving over interval [ 1.61000e+01, 1.62000e+01]
# [     409] ==============================================================
# [     411] ==============================================================
# [     411] Solving over interval [ 1.62000e+01, 1.63000e+01]
# [     411] ==============================================================
# [     414] ==============================================================
# [     414] Solving over interval [ 1.63000e+01, 1.64000e+01]
# [     414] ==============================================================
# [     416] ==============================================================
# [     416] Solving over interval [ 1.64000e+01, 1.65000e+01]
# [     416] ==============================================================
# [     418] ==============================================================
# [     418] Solving over interval [ 1.65000e+01, 1.66000e+01]
# [     418] ==============================================================
# [     421] ==============================================================
# [     421] Solving over interval [ 1.66000e+01, 1.67000e+01]
# [     421] ==============================================================
# [     424] ==============================================================
# [     424] Solving over interval [ 1.67000e+01, 1.68000e+01]
# [     424] ==============================================================
# [     426] ==============================================================
# [     426] Solving over interval [ 1.68000e+01, 1.69000e+01]
# [     426] ==============================================================
# [     429] ==============================================================
# [     429] Solving over interval [ 1.69000e+01, 1.70000e+01]
# [     429] ==============================================================
# [     431] ==============================================================
# [     431] Solving over interval [ 1.70000e+01, 1.71000e+01]
# [     431] ==============================================================
# [     434] ==============================================================
# [     434] Solving over interval [ 1.71000e+01, 1.72000e+01]
# [     434] ==============================================================
# [     436] ==============================================================
# [     436] Solving over interval [ 1.72000e+01, 1.73000e+01]
# [     436] ==============================================================
# [     438] ==============================================================
# [     438] Solving over interval [ 1.73000e+01, 1.74000e+01]
# [     438] ==============================================================
# [     441] ==============================================================
# [     441] Solving over interval [ 1.74000e+01, 1.75000e+01]
# [     441] ==============================================================
# [     444] ==============================================================
# [     444] Solving over interval [ 1.75000e+01, 1.76000e+01]
# [     444] ==============================================================
# [     446] ==============================================================
# [     446] Solving over interval [ 1.76000e+01, 1.77000e+01]
# [     446] ==============================================================
# [     449] ==============================================================
# [     449] Solving over interval [ 1.77000e+01, 1.78000e+01]
# [     449] ==============================================================
# [     451] ==============================================================
# [     451] Solving over interval [ 1.78000e+01, 1.79000e+01]
# [     451] ==============================================================
# [     454] ==============================================================
# [     454] Solving over interval [ 1.79000e+01, 1.80000e+01]
# [     454] ==============================================================
# [     456] ==============================================================
# [     456] Solving over interval [ 1.80000e+01, 1.81000e+01]
# [     456] ==============================================================
# [     459] ==============================================================
# [     459] Solving over interval [ 1.81000e+01, 1.82000e+01]
# [     459] ==============================================================
# [     461] ==============================================================
# [     461] Solving over interval [ 1.82000e+01, 1.83000e+01]
# [     461] ==============================================================
# [     464] ==============================================================
# [     464] Solving over interval [ 1.83000e+01, 1.84000e+01]
# [     464] ==============================================================
# [     466] ==============================================================
# [     466] Solving over interval [ 1.84000e+01, 1.85000e+01]
# [     466] ==============================================================
# [     469] ==============================================================
# [     469] Solving over interval [ 1.85000e+01, 1.86000e+01]
# [     469] ==============================================================
# [     471] ==============================================================
# [     471] Solving over interval [ 1.86000e+01, 1.87000e+01]
# [     471] ==============================================================
# [     474] ==============================================================
# [     474] Solving over interval [ 1.87000e+01, 1.88000e+01]
# [     474] ==============================================================
# [     476] ==============================================================
# [     476] Solving over interval [ 1.88000e+01, 1.89000e+01]
# [     476] ==============================================================
# [     478] ==============================================================
# [     478] Solving over interval [ 1.89000e+01, 1.90000e+01]
# [     478] ==============================================================
# [     481] ==============================================================
# [     481] Solving over interval [ 1.90000e+01, 1.91000e+01]
# [     481] ==============================================================
# [     483] ==============================================================
# [     483] Solving over interval [ 1.91000e+01, 1.92000e+01]
# [     483] ==============================================================
# [     486] ==============================================================
# [     486] Solving over interval [ 1.92000e+01, 1.93000e+01]
# [     486] ==============================================================
# [     488] ==============================================================
# [     488] Solving over interval [ 1.93000e+01, 1.94000e+01]
# [     488] ==============================================================
# [     491] ==============================================================
# [     491] Solving over interval [ 1.94000e+01, 1.95000e+01]
# [     491] ==============================================================
# [     493] ==============================================================
# [     493] Solving over interval [ 1.95000e+01, 1.96000e+01]
# [     493] ==============================================================
# [     496] ==============================================================
# [     496] Solving over interval [ 1.96000e+01, 1.97000e+01]
# [     496] ==============================================================
# [     498] ==============================================================
# [     498] Solving over interval [ 1.97000e+01, 1.98000e+01]
# [     498] ==============================================================
# [     501] ==============================================================
# [     501] Solving over interval [ 1.98000e+01, 1.99000e+01]
# [     501] ==============================================================
# [     503] ==============================================================
# [     503] Solving over interval [ 1.99000e+01, 2.00000e+01]
# [     503] ==============================================================
# [     506] ==============================================================
# [     506] Solving over interval [ 2.00000e+01, 2.01000e+01]
# [     506] ==============================================================
# [     508] ==============================================================
# [     508] Solving over interval [ 2.01000e+01, 2.02000e+01]
# [     508] ==============================================================
# [     511] ==============================================================
# [     511] Solving over interval [ 2.02000e+01, 2.03000e+01]
# [     511] ==============================================================
# [     513] ==============================================================
# [     513] Solving over interval [ 2.03000e+01, 2.04000e+01]
# [     513] ==============================================================
# [     516] ==============================================================
# [     516] Solving over interval [ 2.04000e+01, 2.05000e+01]
# [     516] ==============================================================
# [     518] ==============================================================
# [     518] Solving over interval [ 2.05000e+01, 2.06000e+01]
# [     518] ==============================================================
# [     521] ==============================================================
# [     521] Solving over interval [ 2.06000e+01, 2.07000e+01]
# [     521] ==============================================================
# [     523] ==============================================================
# [     523] Solving over interval [ 2.07000e+01, 2.08000e+01]
# [     523] ==============================================================
# [     526] ==============================================================
# [     526] Solving over interval [ 2.08000e+01, 2.09000e+01]
# [     526] ==============================================================
# [     528] ==============================================================
# [     528] Solving over interval [ 2.09000e+01, 2.10000e+01]
# [     528] ==============================================================
# [     531] ==============================================================
# [     531] Solving over interval [ 2.10000e+01, 2.11000e+01]
# [     531] ==============================================================
# [     533] ==============================================================
# [     533] Solving over interval [ 2.11000e+01, 2.12000e+01]
# [     533] ==============================================================
# [     536] ==============================================================
# [     536] Solving over interval [ 2.12000e+01, 2.13000e+01]
# [     536] ==============================================================
# [     538] ==============================================================
# [     538] Solving over interval [ 2.13000e+01, 2.14000e+01]
# [     538] ==============================================================
# [     541] ==============================================================
# [     541] Solving over interval [ 2.14000e+01, 2.15000e+01]
# [     541] ==============================================================
# [     543] ==============================================================
# [     543] Solving over interval [ 2.15000e+01, 2.16000e+01]
# [     543] ==============================================================
# [     546] ==============================================================
# [     546] Solving over interval [ 2.16000e+01, 2.17000e+01]
# [     546] ==============================================================
# [     549] ==============================================================
# [     549] Solving over interval [ 2.17000e+01, 2.18000e+01]
# [     549] ==============================================================
# [     551] ==============================================================
# [     551] Solving over interval [ 2.18000e+01, 2.19000e+01]
# [     551] ==============================================================
# [     554] ==============================================================
# [     554] Solving over interval [ 2.19000e+01, 2.20000e+01]
# [     554] ==============================================================
# [     556] ==============================================================
# [     556] Solving over interval [ 2.20000e+01, 2.21000e+01]
# [     556] ==============================================================
# [     559] ==============================================================
# [     559] Solving over interval [ 2.21000e+01, 2.22000e+01]
# [     559] ==============================================================
# [     561] ==============================================================
# [     561] Solving over interval [ 2.22000e+01, 2.23000e+01]
# [     561] ==============================================================
# [     564] ==============================================================
# [     564] Solving over interval [ 2.23000e+01, 2.24000e+01]
# [     564] ==============================================================
# [     566] ==============================================================
# [     566] Solving over interval [ 2.24000e+01, 2.25000e+01]
# [     566] ==============================================================
# [     569] ==============================================================
# [     569] Solving over interval [ 2.25000e+01, 2.26000e+01]
# [     569] ==============================================================
# [     572] ==============================================================
# [     572] Solving over interval [ 2.26000e+01, 2.27000e+01]
# [     572] ==============================================================
# [     574] ==============================================================
# [     574] Solving over interval [ 2.27000e+01, 2.28000e+01]
# [     574] ==============================================================
# [     577] ==============================================================
# [     577] Solving over interval [ 2.28000e+01, 2.29000e+01]
# [     577] ==============================================================
# [     579] ==============================================================
# [     579] Solving over interval [ 2.29000e+01, 2.30000e+01]
# [     579] ==============================================================
# [     582] ==============================================================
# [     582] Solving over interval [ 2.30000e+01, 2.31000e+01]
# [     582] ==============================================================
# [     584] ==============================================================
# [     584] Solving over interval [ 2.31000e+01, 2.32000e+01]
# [     584] ==============================================================
# [     587] ==============================================================
# [     587] Solving over interval [ 2.32000e+01, 2.33000e+01]
# [     587] ==============================================================
# [     589] ==============================================================
# [     589] Solving over interval [ 2.33000e+01, 2.34000e+01]
# [     589] ==============================================================
# [     592] ==============================================================
# [     592] Solving over interval [ 2.34000e+01, 2.35000e+01]
# [     592] ==============================================================
# [     594] ==============================================================
# [     594] Solving over interval [ 2.35000e+01, 2.36000e+01]
# [     594] ==============================================================
# [     597] ==============================================================
# [     597] Solving over interval [ 2.36000e+01, 2.37000e+01]
# [     597] ==============================================================
# [     599] ==============================================================
# [     599] Solving over interval [ 2.37000e+01, 2.38000e+01]
# [     599] ==============================================================
# [     602] ==============================================================
# [     602] Solving over interval [ 2.38000e+01, 2.39000e+01]
# [     602] ==============================================================
# [     604] ==============================================================
# [     604] Solving over interval [ 2.39000e+01, 2.40000e+01]
# [     604] ==============================================================
# [     607] ==============================================================
# [     607] Solving over interval [ 2.40000e+01, 2.41000e+01]
# [     607] ==============================================================
# [     609] ==============================================================
# [     609] Solving over interval [ 2.41000e+01, 2.42000e+01]
# [     609] ==============================================================
# [     612] ==============================================================
# [     612] Solving over interval [ 2.42000e+01, 2.43000e+01]
# [     612] ==============================================================
# [     614] ==============================================================
# [     614] Solving over interval [ 2.43000e+01, 2.44000e+01]
# [     614] ==============================================================
# [     617] ==============================================================
# [     617] Solving over interval [ 2.44000e+01, 2.45000e+01]
# [     617] ==============================================================
# [     619] ==============================================================
# [     619] Solving over interval [ 2.45000e+01, 2.46000e+01]
# [     619] ==============================================================
# [     622] ==============================================================
# [     622] Solving over interval [ 2.46000e+01, 2.47000e+01]
# [     622] ==============================================================
# [     624] ==============================================================
# [     624] Solving over interval [ 2.47000e+01, 2.48000e+01]
# [     624] ==============================================================
# [     627] ==============================================================
# [     627] Solving over interval [ 2.48000e+01, 2.49000e+01]
# [     627] ==============================================================
# [     629] ==============================================================
# [     629] Solving over interval [ 2.49000e+01, 2.50000e+01]
# [     629] ==============================================================
# 2  nSpace_global

# %% [markdown]
# ## Post-process the solution using ipygany

# %%
# Get dependencies
import sys
sys.path.append('/opt/proteus_visualization')
from hdf5_loader import extract_arrays_metadata, extract_array
import numpy as np
from ipywidgets import Image
from ipywidgets import Play, IntSlider, HBox, link
from ipygany import Scene, Data, Component, PolyMesh, Water, UnderWater, Data, Component, Threshold
from ipydatawidgets import NDArrayWidget

# %%
# Load our data
arrays_metadata = extract_arrays_metadata('./run_data/beji_periodic.h5')

mem_vertices = extract_array(arrays_metadata, 'nodesSpatial_Domain0')
vertices = np.array(mem_vertices[:, 0:2])

indices = extract_array(arrays_metadata, 'elementsSpatial_Domain0')

# This never changes, we extract it only once
bathymetry = extract_array(arrays_metadata, 'bathymetry0_t0')

# Get texture for topography
texture = Image.from_file('./cement.jpg')

# %%
# Define simulation parameters
warp_value = 20.
num_of_steps = 250

# %%
# Caching arrays on the front-end using NDArrayWidgets
h_cached = []
water_vertices_cached = []
for i in range(num_of_steps):
    h = extract_array(arrays_metadata, 'h_t{}'.format(i))

    z_water = h + bathymetry
    water_vertices = np.append(vertices, z_water.reshape((z_water.shape[0], 1)) * warp_value, axis=1).flatten()

    h_cached.append(NDArrayWidget(array=h))
    water_vertices_cached.append(NDArrayWidget(array=water_vertices))

# %%
# Set up ipygany for visualizing the solution 

h_component = Component(name='h', array=h_cached[0])

water_mesh = PolyMesh(
    vertices=water_vertices_cached[0],
    triangle_indices=indices,
    data={'h': [h_component]}
)

actual_water = Threshold(water_mesh, input='h', min=1e-3, max=1000)

floor = PolyMesh(
    vertices=np.append(vertices, bathymetry.reshape((bathymetry.shape[0], 1)) * warp_value, axis=1),
    triangle_indices=indices,
    data={'underwater': [h_component]}
)

water = Water(
    actual_water, 
    under_water_blocks=(UnderWater(floor), ),
    caustics_enabled=True
)

scene = Scene((water, ))

def update_step(change):
    i = change['new']

    h_component.array = h_cached[i]
    water_mesh.vertices = water_vertices_cached[i]

play = Play(description='Step:', min=0, max=num_of_steps-1, value=0, interval=100)
play.observe(update_step, names=['value'])

progress = IntSlider(value=0, step=1, min=0, max=num_of_steps-1)
link((progress, 'value'), (play, 'value'))

display(HBox((play, progress)))

# Visualize solution 
scene
# Out:
# HBox(children=(Play(value=0, description='Step:', max=249), IntSlider(value=0, max=249)))
# Scene(children=[Water(caustics_enabled=True, input=(), parent=Threshold(input='h', max=1000.0, min=0.001, pare…

# %%
# Define some visualization parameters
water.caustics_factor = 0.20
water.under_water_blocks[0].texture = texture
scene.background_color='aliceblue'
