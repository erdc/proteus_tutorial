# %% [markdown]
# # 2D SWFlow - Dam break with three conical obstacles
# ------------------------------------------------------------------------------------------
#
# This notebook uses Proteus to simulate a dam break over "dry land" with three obstacles using the classical Saint-Venant shallow water equations or a hyperbolic Serre--Green-Naghdi model. See [Guermond et al, 2022] for a detailed description of of the hyperbolic SGN model.
#
# The 2D computational domain is defined as D = [0, 75m] x [0, 30m]. The topography is mostly flat except for three conical obstacles.  The water depth left of the dam (positioned at x = 16m) is 1.875m.
#
# This example highlights the different physics of the shallow water models implemented in PROTEUS along with the capabilities to handle dry states. For more details, we refer to the user to the specific run file `dam3bumps.py` or the references listed below.
#
# ### References
#
# - J.-L.GUERMOND, M. QUEZADA de LUNA, B. POPOV, C. KEES, M. FARTHING, Well-balanced second-order finite element approximation of the shallow water equations with friction, SIAM, J. Sci. Comput., 40:6 (2018) A3873--A3901. [https://doi.org/10.1137/17M1122463](https://doi.org/10.1137/17M1122463)
#
# - J.-L. GUERMOND, C. KEES, B. POPOV, E. TOVAR, Hyperbolic relaxation technique for solving the dispersive Serre-       Green-Naghdi equations with topography, J. Comput. Phys., 450 (2022) 110809. [https://doi.org/10.1016/j.jcp.2021.110809](https://doi.org/10.1016/j.jcp.2021.110809)

# %% [markdown]
# # Running the benchmark via the terminal
#
# The `parun` script can be to execute the python script file: `reef_island_runup.py`. There are several argument that can be supplied to the `parun` script to define various runtime options. All available options are listed when executing `parun -h` in the command line. Common command-line options are as follows:
#
# **Option** | **Description**
# :---: | :---:
#  -v   | Print logging information to standard output
#  -O PETSCOPTIONSFILE  | Text file of options to pass to Petsc library
#  -D DATADIR | Set data directory for output storage
#  -l LOGLEVEL | Store runtime information at the log level, 0 = none, 10 = everything
#  -b BATCHFILENAME | Text file of auxiliary commands to execute along with main program
#  -G gatherArchive | Collect data files into single file at end of simulation (will require more computational resources on large runs)
#  -H hotStart | Use the last step in the archive as the initial condition and continue appending to the archive
#  --SWEs | To consider SWEs applications
#
#
# To run the script on more than one rank, one can invoke the following: `mpiexec -n <number of cores>` before the use of `parun` in the command line.

# %% [markdown]
# ## Context options for run file
#
# Most (if not all) Proteus run files `benchmark_name.py` (in this case `reef_island_runup.py`) contain run time options specific to the model at hand. Here are some run time options for this particular example. For exact options, see the run file.
#
# **Option** | **Description**
# :---: | :---:
#  sw_model | sw_model = {0,1} for {SWEs,DSWEs}
#  final_time  | Final time for simulation
#  dt_output | Time interval to output solution
#  still_water_depth | Depth of still water above floor
#  dam_height | Height of water dam above still water
#  dam_x_location | X position of dam
#  cone_amplifier | Amplification of bathymetry cone magnitudes
#
#
# To modify the context options at run time, include the `-C` flag followed by `"option1=True option2=2 ..."`.

# %%
# Clean up previous data directory if it exists
# !rm -r run_data

# %%
# Then we run 
# !PATH=/opt/proteus/linux/bin:$PATH mpiexec -np 4 parun --SWEs dam3Bumps.py -l1 -v -C "refinement=5 final_time=20. cone_amplifier=2." -D run_data
# Out:
# [       0] Running Proteus version 1.8.0.dev0
# Constructing SW2DCV<CompKernelTemplate<2,4,3,3,3,3>());
# Constructing SW2DCV<CompKernelTemplate<2,4,3,3,3,3>());
# Constructing SW2DCV<CompKernelTemplate<2,4,3,3,3,3>());
# Constructing SW2DCV<CompKernelTemplate<2,4,3,3,3,3>());
# 2  nSpace_global
# [       2] Setting initial conditions
# [       3] Starting time stepping
# [       3] ==============================================================
# [       3] Solving over interval [ 0.00000e+00, 1.00000e-03]
# [       3] ==============================================================
# [       3] ==============================================================
# [       3] Solving over interval [ 1.00000e-03, 1.00000e-01]
# [       3] ==============================================================
# [       5] ==============================================================
# [       5] Solving over interval [ 1.00000e-01, 2.00000e-01]
# [       5] ==============================================================
# [       7] ==============================================================
# [       7] Solving over interval [ 2.00000e-01, 3.00000e-01]
# [       7] ==============================================================
# [       9] ==============================================================
# [       9] Solving over interval [ 3.00000e-01, 4.00000e-01]
# [       9] ==============================================================
# [      10] ==============================================================
# [      10] Solving over interval [ 4.00000e-01, 5.00000e-01]
# [      10] ==============================================================
# [      12] ==============================================================
# [      12] Solving over interval [ 5.00000e-01, 6.00000e-01]
# [      12] ==============================================================
# [      13] ==============================================================
# [      13] Solving over interval [ 6.00000e-01, 7.00000e-01]
# [      13] ==============================================================
# [      15] ==============================================================
# [      15] Solving over interval [ 7.00000e-01, 8.00000e-01]
# [      15] ==============================================================
# [      16] ==============================================================
# [      16] Solving over interval [ 8.00000e-01, 9.00000e-01]
# [      16] ==============================================================
# [      18] ==============================================================
# [      18] Solving over interval [ 9.00000e-01, 1.00000e+00]
# [      18] ==============================================================
# [      19] ==============================================================
# [      19] Solving over interval [ 1.00000e+00, 1.10000e+00]
# [      19] ==============================================================
# [      21] ==============================================================
# [      21] Solving over interval [ 1.10000e+00, 1.20000e+00]
# [      21] ==============================================================
# [      22] ==============================================================
# [      22] Solving over interval [ 1.20000e+00, 1.30000e+00]
# [      22] ==============================================================
# [      24] ==============================================================
# [      24] Solving over interval [ 1.30000e+00, 1.40000e+00]
# [      24] ==============================================================
# [      25] ==============================================================
# [      25] Solving over interval [ 1.40000e+00, 1.50000e+00]
# [      25] ==============================================================
# [      27] ==============================================================
# [      27] Solving over interval [ 1.50000e+00, 1.60000e+00]
# [      27] ==============================================================
# [      28] ==============================================================
# [      28] Solving over interval [ 1.60000e+00, 1.70000e+00]
# [      28] ==============================================================
# [      30] ==============================================================
# [      30] Solving over interval [ 1.70000e+00, 1.80000e+00]
# [      30] ==============================================================
# [      31] ==============================================================
# [      31] Solving over interval [ 1.80000e+00, 1.90000e+00]
# [      31] ==============================================================
# [      33] ==============================================================
# [      33] Solving over interval [ 1.90000e+00, 2.00000e+00]
# [      33] ==============================================================
# [      35] ==============================================================
# [      35] Solving over interval [ 2.00000e+00, 2.10000e+00]
# [      35] ==============================================================
# [      36] ==============================================================
# [      36] Solving over interval [ 2.10000e+00, 2.20000e+00]
# [      36] ==============================================================
# [      38] ==============================================================
# [      38] Solving over interval [ 2.20000e+00, 2.30000e+00]
# [      38] ==============================================================
# [      40] ==============================================================
# [      40] Solving over interval [ 2.30000e+00, 2.40000e+00]
# [      40] ==============================================================
# [      41] ==============================================================
# [      41] Solving over interval [ 2.40000e+00, 2.50000e+00]
# [      41] ==============================================================
# [      43] ==============================================================
# [      43] Solving over interval [ 2.50000e+00, 2.60000e+00]
# [      43] ==============================================================
# [      44] ==============================================================
# [      44] Solving over interval [ 2.60000e+00, 2.70000e+00]
# [      44] ==============================================================
# [      46] ==============================================================
# [      46] Solving over interval [ 2.70000e+00, 2.80000e+00]
# [      46] ==============================================================
# [      47] ==============================================================
# [      47] Solving over interval [ 2.80000e+00, 2.90000e+00]
# [      47] ==============================================================
# [      49] ==============================================================
# [      49] Solving over interval [ 2.90000e+00, 3.00000e+00]
# [      49] ==============================================================
# [      50] ==============================================================
# [      50] Solving over interval [ 3.00000e+00, 3.10000e+00]
# [      50] ==============================================================
# [      52] ==============================================================
# [      52] Solving over interval [ 3.10000e+00, 3.20000e+00]
# [      52] ==============================================================
# [      53] ==============================================================
# [      53] Solving over interval [ 3.20000e+00, 3.30000e+00]
# [      53] ==============================================================
# [      55] ==============================================================
# [      55] Solving over interval [ 3.30000e+00, 3.40000e+00]
# [      55] ==============================================================
# [      57] ==============================================================
# [      57] Solving over interval [ 3.40000e+00, 3.50000e+00]
# [      57] ==============================================================
# [      58] ==============================================================
# [      58] Solving over interval [ 3.50000e+00, 3.60000e+00]
# [      58] ==============================================================
# [      60] ==============================================================
# [      60] Solving over interval [ 3.60000e+00, 3.70000e+00]
# [      60] ==============================================================
# [      61] ==============================================================
# [      61] Solving over interval [ 3.70000e+00, 3.80000e+00]
# [      61] ==============================================================
# [      63] ==============================================================
# [      63] Solving over interval [ 3.80000e+00, 3.90000e+00]
# [      63] ==============================================================
# [      65] ==============================================================
# [      65] Solving over interval [ 3.90000e+00, 4.00000e+00]
# [      65] ==============================================================
# [      66] ==============================================================
# [      66] Solving over interval [ 4.00000e+00, 4.10000e+00]
# [      66] ==============================================================
# [      68] ==============================================================
# [      68] Solving over interval [ 4.10000e+00, 4.20000e+00]
# [      68] ==============================================================
# [      69] ==============================================================
# [      69] Solving over interval [ 4.20000e+00, 4.30000e+00]
# [      69] ==============================================================
# [      71] ==============================================================
# [      71] Solving over interval [ 4.30000e+00, 4.40000e+00]
# [      71] ==============================================================
# [      72] ==============================================================
# [      72] Solving over interval [ 4.40000e+00, 4.50000e+00]
# [      72] ==============================================================
# [      74] ==============================================================
# [      74] Solving over interval [ 4.50000e+00, 4.60000e+00]
# [      74] ==============================================================
# [      75] ==============================================================
# [      75] Solving over interval [ 4.60000e+00, 4.70000e+00]
# [      75] ==============================================================
# [      77] ==============================================================
# [      77] Solving over interval [ 4.70000e+00, 4.80000e+00]
# [      77] ==============================================================
# [      79] ==============================================================
# [      79] Solving over interval [ 4.80000e+00, 4.90000e+00]
# [      79] ==============================================================
# [      80] ==============================================================
# [      80] Solving over interval [ 4.90000e+00, 5.00000e+00]
# [      80] ==============================================================
# [      82] ==============================================================
# [      82] Solving over interval [ 5.00000e+00, 5.10000e+00]
# [      82] ==============================================================
# [      83] ==============================================================
# [      83] Solving over interval [ 5.10000e+00, 5.20000e+00]
# [      83] ==============================================================
# [      85] ==============================================================
# [      85] Solving over interval [ 5.20000e+00, 5.30000e+00]
# [      85] ==============================================================
# [      87] ==============================================================
# [      87] Solving over interval [ 5.30000e+00, 5.40000e+00]
# [      87] ==============================================================
# [      88] ==============================================================
# [      88] Solving over interval [ 5.40000e+00, 5.50000e+00]
# [      88] ==============================================================
# [      90] ==============================================================
# [      90] Solving over interval [ 5.50000e+00, 5.60000e+00]
# [      90] ==============================================================
# [      92] ==============================================================
# [      92] Solving over interval [ 5.60000e+00, 5.70000e+00]
# [      92] ==============================================================
# [      93] ==============================================================
# [      93] Solving over interval [ 5.70000e+00, 5.80000e+00]
# [      93] ==============================================================
# [      95] ==============================================================
# [      95] Solving over interval [ 5.80000e+00, 5.90000e+00]
# [      95] ==============================================================
# [      97] ==============================================================
# [      97] Solving over interval [ 5.90000e+00, 6.00000e+00]
# [      97] ==============================================================
# [      98] ==============================================================
# [      98] Solving over interval [ 6.00000e+00, 6.10000e+00]
# [      98] ==============================================================
# [     100] ==============================================================
# [     100] Solving over interval [ 6.10000e+00, 6.20000e+00]
# [     100] ==============================================================
# [     101] ==============================================================
# [     101] Solving over interval [ 6.20000e+00, 6.30000e+00]
# [     101] ==============================================================
# [     103] ==============================================================
# [     103] Solving over interval [ 6.30000e+00, 6.40000e+00]
# [     103] ==============================================================
# [     104] ==============================================================
# [     104] Solving over interval [ 6.40000e+00, 6.50000e+00]
# [     104] ==============================================================
# [     106] ==============================================================
# [     106] Solving over interval [ 6.50000e+00, 6.60000e+00]
# [     106] ==============================================================
# [     108] ==============================================================
# [     108] Solving over interval [ 6.60000e+00, 6.70000e+00]
# [     108] ==============================================================
# [     109] ==============================================================
# [     109] Solving over interval [ 6.70000e+00, 6.80000e+00]
# [     109] ==============================================================
# [     111] ==============================================================
# [     111] Solving over interval [ 6.80000e+00, 6.90000e+00]
# [     111] ==============================================================
# [     112] ==============================================================
# [     112] Solving over interval [ 6.90000e+00, 7.00000e+00]
# [     112] ==============================================================
# [     114] ==============================================================
# [     114] Solving over interval [ 7.00000e+00, 7.10000e+00]
# [     114] ==============================================================
# [     116] ==============================================================
# [     116] Solving over interval [ 7.10000e+00, 7.20000e+00]
# [     116] ==============================================================
# [     117] ==============================================================
# [     117] Solving over interval [ 7.20000e+00, 7.30000e+00]
# [     117] ==============================================================
# [     119] ==============================================================
# [     119] Solving over interval [ 7.30000e+00, 7.40000e+00]
# [     119] ==============================================================
# [     120] ==============================================================
# [     120] Solving over interval [ 7.40000e+00, 7.50000e+00]
# [     120] ==============================================================
# [     122] ==============================================================
# [     122] Solving over interval [ 7.50000e+00, 7.60000e+00]
# [     122] ==============================================================
# [     123] ==============================================================
# [     123] Solving over interval [ 7.60000e+00, 7.70000e+00]
# [     123] ==============================================================
# [     125] ==============================================================
# [     125] Solving over interval [ 7.70000e+00, 7.80000e+00]
# [     125] ==============================================================
# [     127] ==============================================================
# [     127] Solving over interval [ 7.80000e+00, 7.90000e+00]
# [     127] ==============================================================
# [     128] ==============================================================
# [     128] Solving over interval [ 7.90000e+00, 8.00000e+00]
# [     128] ==============================================================
# [     130] ==============================================================
# [     130] Solving over interval [ 8.00000e+00, 8.10000e+00]
# [     130] ==============================================================
# [     132] ==============================================================
# [     132] Solving over interval [ 8.10000e+00, 8.20000e+00]
# [     132] ==============================================================
# [     133] ==============================================================
# [     133] Solving over interval [ 8.20000e+00, 8.30000e+00]
# [     133] ==============================================================
# [     135] ==============================================================
# [     135] Solving over interval [ 8.30000e+00, 8.40000e+00]
# [     135] ==============================================================
# [     136] ==============================================================
# [     136] Solving over interval [ 8.40000e+00, 8.50000e+00]
# [     136] ==============================================================
# [     138] ==============================================================
# [     138] Solving over interval [ 8.50000e+00, 8.60000e+00]
# [     138] ==============================================================
# [     140] ==============================================================
# [     140] Solving over interval [ 8.60000e+00, 8.70000e+00]
# [     140] ==============================================================
# [     141] ==============================================================
# [     141] Solving over interval [ 8.70000e+00, 8.80000e+00]
# [     141] ==============================================================
# [     142] ==============================================================
# [     142] Solving over interval [ 8.80000e+00, 8.90000e+00]
# [     142] ==============================================================
# [     144] ==============================================================
# [     144] Solving over interval [ 8.90000e+00, 9.00000e+00]
# [     144] ==============================================================
# [     146] ==============================================================
# [     146] Solving over interval [ 9.00000e+00, 9.10000e+00]
# [     146] ==============================================================
# [     147] ==============================================================
# [     147] Solving over interval [ 9.10000e+00, 9.20000e+00]
# [     147] ==============================================================
# [     149] ==============================================================
# [     149] Solving over interval [ 9.20000e+00, 9.30000e+00]
# [     149] ==============================================================
# [     150] ==============================================================
# [     150] Solving over interval [ 9.30000e+00, 9.40000e+00]
# [     150] ==============================================================
# [     152] ==============================================================
# [     152] Solving over interval [ 9.40000e+00, 9.50000e+00]
# [     152] ==============================================================
# [     153] ==============================================================
# [     153] Solving over interval [ 9.50000e+00, 9.60000e+00]
# [     153] ==============================================================
# [     155] ==============================================================
# [     155] Solving over interval [ 9.60000e+00, 9.70000e+00]
# [     155] ==============================================================
# [     156] ==============================================================
# [     156] Solving over interval [ 9.70000e+00, 9.80000e+00]
# [     156] ==============================================================
# [     158] ==============================================================
# [     158] Solving over interval [ 9.80000e+00, 9.90000e+00]
# [     158] ==============================================================
# [     159] ==============================================================
# [     159] Solving over interval [ 9.90000e+00, 1.00000e+01]
# [     159] ==============================================================
# [     161] ==============================================================
# [     161] Solving over interval [ 1.00000e+01, 1.01000e+01]
# [     161] ==============================================================
# [     162] ==============================================================
# [     162] Solving over interval [ 1.01000e+01, 1.02000e+01]
# [     162] ==============================================================
# [     163] ==============================================================
# [     163] Solving over interval [ 1.02000e+01, 1.03000e+01]
# [     163] ==============================================================
# [     165] ==============================================================
# [     165] Solving over interval [ 1.03000e+01, 1.04000e+01]
# [     165] ==============================================================
# [     166] ==============================================================
# [     166] Solving over interval [ 1.04000e+01, 1.05000e+01]
# [     166] ==============================================================
# [     168] ==============================================================
# [     168] Solving over interval [ 1.05000e+01, 1.06000e+01]
# [     168] ==============================================================
# [     169] ==============================================================
# [     169] Solving over interval [ 1.06000e+01, 1.07000e+01]
# [     169] ==============================================================
# [     171] ==============================================================
# [     171] Solving over interval [ 1.07000e+01, 1.08000e+01]
# [     171] ==============================================================
# [     172] ==============================================================
# [     172] Solving over interval [ 1.08000e+01, 1.09000e+01]
# [     172] ==============================================================
# [     173] ==============================================================
# [     173] Solving over interval [ 1.09000e+01, 1.10000e+01]
# [     173] ==============================================================
# [     175] ==============================================================
# [     175] Solving over interval [ 1.10000e+01, 1.11000e+01]
# [     175] ==============================================================
# [     176] ==============================================================
# [     176] Solving over interval [ 1.11000e+01, 1.12000e+01]
# [     176] ==============================================================
# [     178] ==============================================================
# [     178] Solving over interval [ 1.12000e+01, 1.13000e+01]
# [     178] ==============================================================
# [     179] ==============================================================
# [     179] Solving over interval [ 1.13000e+01, 1.14000e+01]
# [     179] ==============================================================
# [     180] ==============================================================
# [     180] Solving over interval [ 1.14000e+01, 1.15000e+01]
# [     180] ==============================================================
# [     182] ==============================================================
# [     182] Solving over interval [ 1.15000e+01, 1.16000e+01]
# [     182] ==============================================================
# [     183] ==============================================================
# [     183] Solving over interval [ 1.16000e+01, 1.17000e+01]
# [     183] ==============================================================
# [     185] ==============================================================
# [     185] Solving over interval [ 1.17000e+01, 1.18000e+01]
# [     185] ==============================================================
# [     186] ==============================================================
# [     186] Solving over interval [ 1.18000e+01, 1.19000e+01]
# [     186] ==============================================================
# [     187] ==============================================================
# [     187] Solving over interval [ 1.19000e+01, 1.20000e+01]
# [     187] ==============================================================
# [     189] ==============================================================
# [     189] Solving over interval [ 1.20000e+01, 1.21000e+01]
# [     189] ==============================================================
# [     190] ==============================================================
# [     190] Solving over interval [ 1.21000e+01, 1.22000e+01]
# [     190] ==============================================================
# [     191] ==============================================================
# [     191] Solving over interval [ 1.22000e+01, 1.23000e+01]
# [     191] ==============================================================
# [     193] ==============================================================
# [     193] Solving over interval [ 1.23000e+01, 1.24000e+01]
# [     193] ==============================================================
# [     194] ==============================================================
# [     194] Solving over interval [ 1.24000e+01, 1.25000e+01]
# [     194] ==============================================================
# [     196] ==============================================================
# [     196] Solving over interval [ 1.25000e+01, 1.26000e+01]
# [     196] ==============================================================
# [     197] ==============================================================
# [     197] Solving over interval [ 1.26000e+01, 1.27000e+01]
# [     197] ==============================================================
# [     198] ==============================================================
# [     198] Solving over interval [ 1.27000e+01, 1.28000e+01]
# [     198] ==============================================================
# [     200] ==============================================================
# [     200] Solving over interval [ 1.28000e+01, 1.29000e+01]
# [     200] ==============================================================
# [     201] ==============================================================
# [     201] Solving over interval [ 1.29000e+01, 1.30000e+01]
# [     201] ==============================================================
# [     202] ==============================================================
# [     202] Solving over interval [ 1.30000e+01, 1.31000e+01]
# [     202] ==============================================================
# [     204] ==============================================================
# [     204] Solving over interval [ 1.31000e+01, 1.32000e+01]
# [     204] ==============================================================
# [     205] ==============================================================
# [     205] Solving over interval [ 1.32000e+01, 1.33000e+01]
# [     205] ==============================================================
# [     207] ==============================================================
# [     207] Solving over interval [ 1.33000e+01, 1.34000e+01]
# [     207] ==============================================================
# [     208] ==============================================================
# [     208] Solving over interval [ 1.34000e+01, 1.35000e+01]
# [     208] ==============================================================
# [     210] ==============================================================
# [     210] Solving over interval [ 1.35000e+01, 1.36000e+01]
# [     210] ==============================================================
# [     211] ==============================================================
# [     211] Solving over interval [ 1.36000e+01, 1.37000e+01]
# [     211] ==============================================================
# [     212] ==============================================================
# [     212] Solving over interval [ 1.37000e+01, 1.38000e+01]
# [     212] ==============================================================
# [     214] ==============================================================
# [     214] Solving over interval [ 1.38000e+01, 1.39000e+01]
# [     214] ==============================================================
# [     215] ==============================================================
# [     215] Solving over interval [ 1.39000e+01, 1.40000e+01]
# [     215] ==============================================================
# [     217] ==============================================================
# [     217] Solving over interval [ 1.40000e+01, 1.41000e+01]
# [     217] ==============================================================
# [     218] ==============================================================
# [     218] Solving over interval [ 1.41000e+01, 1.42000e+01]
# [     218] ==============================================================
# [     220] ==============================================================
# [     220] Solving over interval [ 1.42000e+01, 1.43000e+01]
# [     220] ==============================================================
# [     221] ==============================================================
# [     221] Solving over interval [ 1.43000e+01, 1.44000e+01]
# [     221] ==============================================================
# [     222] ==============================================================
# [     222] Solving over interval [ 1.44000e+01, 1.45000e+01]
# [     222] ==============================================================
# [     223] ==============================================================
# [     223] Solving over interval [ 1.45000e+01, 1.46000e+01]
# [     223] ==============================================================
# [     225] ==============================================================
# [     225] Solving over interval [ 1.46000e+01, 1.47000e+01]
# [     225] ==============================================================
# [     226] ==============================================================
# [     226] Solving over interval [ 1.47000e+01, 1.48000e+01]
# [     226] ==============================================================
# [     227] ==============================================================
# [     227] Solving over interval [ 1.48000e+01, 1.49000e+01]
# [     227] ==============================================================
# [     229] ==============================================================
# [     229] Solving over interval [ 1.49000e+01, 1.50000e+01]
# [     229] ==============================================================
# [     230] ==============================================================
# [     230] Solving over interval [ 1.50000e+01, 1.51000e+01]
# [     230] ==============================================================
# [     231] ==============================================================
# [     231] Solving over interval [ 1.51000e+01, 1.52000e+01]
# [     231] ==============================================================
# [     232] ==============================================================
# [     232] Solving over interval [ 1.52000e+01, 1.53000e+01]
# [     232] ==============================================================
# [     234] ==============================================================
# [     234] Solving over interval [ 1.53000e+01, 1.54000e+01]
# [     234] ==============================================================
# [     235] ==============================================================
# [     235] Solving over interval [ 1.54000e+01, 1.55000e+01]
# [     235] ==============================================================
# [     236] ==============================================================
# [     236] Solving over interval [ 1.55000e+01, 1.56000e+01]
# [     236] ==============================================================
# [     238] ==============================================================
# [     238] Solving over interval [ 1.56000e+01, 1.57000e+01]
# [     238] ==============================================================
# [     239] ==============================================================
# [     239] Solving over interval [ 1.57000e+01, 1.58000e+01]
# [     239] ==============================================================
# [     240] ==============================================================
# [     240] Solving over interval [ 1.58000e+01, 1.59000e+01]
# [     240] ==============================================================
# [     241] ==============================================================
# [     241] Solving over interval [ 1.59000e+01, 1.60000e+01]
# [     241] ==============================================================
# [     243] ==============================================================
# [     243] Solving over interval [ 1.60000e+01, 1.61000e+01]
# [     243] ==============================================================
# [     244] ==============================================================
# [     244] Solving over interval [ 1.61000e+01, 1.62000e+01]
# [     244] ==============================================================
# [     245] ==============================================================
# [     245] Solving over interval [ 1.62000e+01, 1.63000e+01]
# [     245] ==============================================================
# [     246] ==============================================================
# [     246] Solving over interval [ 1.63000e+01, 1.64000e+01]
# [     246] ==============================================================
# [     248] ==============================================================
# [     248] Solving over interval [ 1.64000e+01, 1.65000e+01]
# [     248] ==============================================================
# [     249] ==============================================================
# [     249] Solving over interval [ 1.65000e+01, 1.66000e+01]
# [     249] ==============================================================
# [     250] ==============================================================
# [     250] Solving over interval [ 1.66000e+01, 1.67000e+01]
# [     250] ==============================================================
# [     252] ==============================================================
# [     252] Solving over interval [ 1.67000e+01, 1.68000e+01]
# [     252] ==============================================================
# [     253] ==============================================================
# [     253] Solving over interval [ 1.68000e+01, 1.69000e+01]
# [     253] ==============================================================
# [     254] ==============================================================
# [     254] Solving over interval [ 1.69000e+01, 1.70000e+01]
# [     254] ==============================================================
# [     255] ==============================================================
# [     255] Solving over interval [ 1.70000e+01, 1.71000e+01]
# [     255] ==============================================================
# [     257] ==============================================================
# [     257] Solving over interval [ 1.71000e+01, 1.72000e+01]
# [     257] ==============================================================
# [     258] ==============================================================
# [     258] Solving over interval [ 1.72000e+01, 1.73000e+01]
# [     258] ==============================================================
# [     259] ==============================================================
# [     259] Solving over interval [ 1.73000e+01, 1.74000e+01]
# [     259] ==============================================================
# [     260] ==============================================================
# [     260] Solving over interval [ 1.74000e+01, 1.75000e+01]
# [     260] ==============================================================
# [     262] ==============================================================
# [     262] Solving over interval [ 1.75000e+01, 1.76000e+01]
# [     262] ==============================================================
# [     263] ==============================================================
# [     263] Solving over interval [ 1.76000e+01, 1.77000e+01]
# [     263] ==============================================================
# [     264] ==============================================================
# [     264] Solving over interval [ 1.77000e+01, 1.78000e+01]
# [     264] ==============================================================
# [     266] ==============================================================
# [     266] Solving over interval [ 1.78000e+01, 1.79000e+01]
# [     266] ==============================================================
# [     267] ==============================================================
# [     267] Solving over interval [ 1.79000e+01, 1.80000e+01]
# [     267] ==============================================================
# [     268] ==============================================================
# [     268] Solving over interval [ 1.80000e+01, 1.81000e+01]
# [     268] ==============================================================
# [     269] ==============================================================
# [     269] Solving over interval [ 1.81000e+01, 1.82000e+01]
# [     269] ==============================================================
# [     271] ==============================================================
# [     271] Solving over interval [ 1.82000e+01, 1.83000e+01]
# [     271] ==============================================================
# [     272] ==============================================================
# [     272] Solving over interval [ 1.83000e+01, 1.84000e+01]
# [     272] ==============================================================
# [     273] ==============================================================
# [     273] Solving over interval [ 1.84000e+01, 1.85000e+01]
# [     273] ==============================================================
# [     275] ==============================================================
# [     275] Solving over interval [ 1.85000e+01, 1.86000e+01]
# [     275] ==============================================================
# [     276] ==============================================================
# [     276] Solving over interval [ 1.86000e+01, 1.87000e+01]
# [     276] ==============================================================
# [     277] ==============================================================
# [     277] Solving over interval [ 1.87000e+01, 1.88000e+01]
# [     277] ==============================================================
# [     278] ==============================================================
# [     278] Solving over interval [ 1.88000e+01, 1.89000e+01]
# [     278] ==============================================================
# [     280] ==============================================================
# [     280] Solving over interval [ 1.89000e+01, 1.90000e+01]
# [     280] ==============================================================
# [     281] ==============================================================
# [     281] Solving over interval [ 1.90000e+01, 1.91000e+01]
# [     281] ==============================================================
# [     282] ==============================================================
# [     282] Solving over interval [ 1.91000e+01, 1.92000e+01]
# [     282] ==============================================================
# [     283] ==============================================================
# [     283] Solving over interval [ 1.92000e+01, 1.93000e+01]
# [     283] ==============================================================
# [     285] ==============================================================
# [     285] Solving over interval [ 1.93000e+01, 1.94000e+01]
# [     285] ==============================================================
# [     286] ==============================================================
# [     286] Solving over interval [ 1.94000e+01, 1.95000e+01]
# [     286] ==============================================================
# [     287] ==============================================================
# [     287] Solving over interval [ 1.95000e+01, 1.96000e+01]
# [     287] ==============================================================
# [     288] ==============================================================
# [     288] Solving over interval [ 1.96000e+01, 1.97000e+01]
# [     288] ==============================================================
# [     289] ==============================================================
# [     289] Solving over interval [ 1.97000e+01, 1.98000e+01]
# [     289] ==============================================================
# [     291] ==============================================================
# [     291] Solving over interval [ 1.98000e+01, 1.99000e+01]
# [     291] ==============================================================
# [     292] ==============================================================
# [     292] Solving over interval [ 1.99000e+01, 2.00000e+01]
# [     292] ==============================================================
# 2  nSpace_global
# 2  nSpace_global
# 2  nSpace_global

# %% [markdown]
# ## Post-process the solution using ipygany

# %%
# Get dependencies
import sys
sys.path.append('/opt/proteus_visualization')
from hdf5_loader import extract_arrays_metadata, extract_array
import numpy as np
from ipywidgets import Image
from ipywidgets import Play, IntSlider, HBox, link
from ipygany import Scene, Data, Component, PolyMesh, Water, UnderWater, Data, Component, Threshold
from ipydatawidgets import NDArrayWidget

# %%
# Load our data
arrays_metadata = extract_arrays_metadata('./run_data/dam3Bumps.h5')

mem_vertices = extract_array(arrays_metadata, 'nodesSpatial_Domain0')
vertices = np.array(mem_vertices[:, 0:2])

indices = extract_array(arrays_metadata, 'elementsSpatial_Domain0')

# This never changes, we extract it only once
bathymetry = extract_array(arrays_metadata, 'bathymetry0_t0')

# Get texture for topography
texture = Image.from_file('./wood_texture.jpg')

# %%
# Define simulation parameters
warp_value = 5.
num_of_steps = 200

# %%
# Caching arrays on the front-end using NDArrayWidgets
h_cached = []
water_vertices_cached = []
for i in range(num_of_steps):
    h = extract_array(arrays_metadata, 'h_t{}'.format(i))

    z_water = h + bathymetry
    water_vertices = np.append(vertices, z_water.reshape((z_water.shape[0], 1)) * warp_value, axis=1).flatten()

    h_cached.append(NDArrayWidget(array=h))
    water_vertices_cached.append(NDArrayWidget(array=water_vertices))

# %%
# Set up ipygany for visualizing the solution 

h_component = Component(name='h', array=h_cached[0])

water_mesh = PolyMesh(
    vertices=water_vertices_cached[0],
    triangle_indices=indices,
    data={'h': [h_component]}
)

actual_water = Threshold(water_mesh, input='h', min=1e-3, max=1000)

floor = PolyMesh(
    vertices=np.append(vertices, bathymetry.reshape((bathymetry.shape[0], 1)) * warp_value, axis=1),
    triangle_indices=indices,
    data={'underwater': [h_component]}
)

water = Water(
    actual_water, 
    under_water_blocks=(UnderWater(floor), ),
    caustics_enabled=True
)

scene = Scene((water, ))

def update_step(change):
    i = change['new']

    h_component.array = h_cached[i]
    water_mesh.vertices = water_vertices_cached[i]

play = Play(description='Step:', min=0, max=num_of_steps-1, value=0, interval=100)
play.observe(update_step, names=['value'])

progress = IntSlider(value=0, step=1, min=0, max=num_of_steps-1)
link((progress, 'value'), (play, 'value'))

display(HBox((play, progress)))

# Visualize solution 
scene

# %%
# Define some visualization parameters
water.caustics_factor = 0.20
water.under_water_blocks[0].texture = texture
scene.background_color='aliceblue'
